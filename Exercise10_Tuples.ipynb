# %%
#Creating a tuple
a=(4,5,6,7,8,9)
print(a)
# Out:
# (4, 5, 6, 7, 8, 9)

# %%
#To change element in tuple
a=(4,5,6,7)
a=a[:1]+(9,)+a[2:]
print(a)
# Out:
# (4, 9, 6, 7)

# %%
#Swapping of two numbers
x=7
y=8
x,y=y,x
print(x,y)
# Out:
# 8 7

# %%
#List of tuples
student=[("Reena",20),("Ranjana",18),("Sureka",19)]
print(student)
sort=sorted(student,key=lambda x:x[1])
print(sort)
sort1=sorted(student,key=lambda x:x[0])
print(sort1)
# Out:
# [('Reena', 20), ('Ranjana', 18), ('Sureka', 19)]
# [('Ranjana', 18), ('Sureka', 19), ('Reena', 20)]
# [('Ranjana', 18), ('Reena', 20), ('Sureka', 19)]

# %%
#Tuple slicing
a=(2,4,6,7,8)
print(a[::-1])
print(a[0::2])
print(a[-5:])
print(a[0:])
print(a[::2])
# Out:
# (8, 7, 6, 4, 2)
# (2, 6, 8)
# (2, 4, 6, 7, 8)
# (2, 4, 6, 7, 8)
# (2, 6, 8)

# %%
#Count the no.of elements in the tuple
t=(1,2,3,4,5,6,7,8,2,2)
c=t.count(2)
print(c)
# Out:
# 3

# %%
#For loop in tuple
sports=("Football","Cricket","Volleyball","Throwball")
for i in sports:
    print(i)
for i in range(len(sports)):
    print(sports[i])
# Out:
# Football
# Cricket
# Volleyball
# Throwball
# Football
# Cricket
# Volleyball
# Throwball

# %%
#Tuple unpacking
data=(154,"Sureka",19)
rollno,name,age=data
print(rollno,name,age)
# Out:
# 154 Sureka 19

# %%
#List and Tuple Datatype transformation
l=[1,2,3]
t=[4,5,6]
print(l,t)
print(list(t),tuple(l))
# Out:
# [1, 2, 3] [4, 5, 6]
# [4, 5, 6] (1, 2, 3)

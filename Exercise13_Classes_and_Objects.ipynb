# %%
#class and object example 01
class student1:
    def show(self):
        print("Welcome Sureka")
d=student1()
d.show()
# Out:
# Welcome Sureka

# %%
#class and object example 02
class sum:
    def add(self,a,b):
        print(a+b)
s=sum()
s.add(6,4)

# %%
#student details
class student:
    def __init__(self, name, grade):
        self.name=name
        self.grade=grade
    def display(self):
        print("Name:", self.name)
        print("Grade:", self.grade)
s1=student("Sureka","O+")
s1.display()
s2=student("Ranjana", "A+")
s2.display()
# Out:
# Name: Sureka
# Grade: O+
# Name: Ranjana
# Grade: A+

# %%
#student grade details
class student:
    def __init__(self,name, rollno, marks):
        self.name=name
        self.rollno=rollno
        self.marks=marks
    def display(self):
        print("Name:", self.name) 
        print("Roll Number:", self.rollno) 
        print("Marks:", self.marks)
    def average (self): 
        return sum(self.marks)/3
    def grade(self):
        avg=self.average()
        if avg>=90:
            return "A"
        elif avg>=75:
            return "B"
        elif avg>=65:
            return "C"
        else:
            return "D"
s1=student("Sureka", 154, [99,94,92])
s1.display()
print("Average:", s1.average()) 
print("Grade:", s1.grade())
# Out:
# Name: Sureka
# Roll Number: 154
# Marks: [99, 94, 92]
# Average: 95.0
# Grade: A

# %%
#bank account details
class bank_account:
    def __init__(self,account_holder, balance=0):
        self.account_holder=account_holder
        self.balance=balance
    def deposit(self, amount):
        self.balance+=amount
        print(f"Deposit: {amount}, New Balance: {self.balance}")
    def withdraw(self, amount):
        if self.balance>=amount:
            self.balance-=amount
            print(f"Withdraw: {amount}, New Balance: {self.balance}")
        else:
            print("Insufficient Balance")
account=bank_account("Ashifa", 1000)
account.deposit (2000)
account.withdraw(1000)
account.deposit (4000)
account.withdraw (2000)
# Out:
# Deposit: 2000, New Balance: 3000
# Withdraw: 1000, New Balance: 2000
# Deposit: 4000, New Balance: 6000
# Withdraw: 2000, New Balance: 4000

# %%
#bank account details with user input
class bank_account:
    def __init__(self, account_holder, balance=0):
        self.account_holder=account_holder
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print(f"Deposit: {amount}, New Balance: {self.balance}")
    def withdraw(self,amount):
        if self.balance>=amount:
            self.balance-=amount
            print(f"Withdraw: {amount}, New Balance: {self.balance}")
        else:
            print("Insufficient Balance")
name=input("Enter the name:")
print("Account_holder:", name)
account=bank_account(name,2000)
deposit=int(input("Enter the amount to deposit:"))
account.deposit(deposit)
withdraw=int(input("Enter the amount to withdraw:"))
account.withdraw(withdraw)
# Out:
# Enter the name: Sureka M
# Account_holder: Sureka M
# Enter the amount to deposit: 2000
# Deposit: 2000, New Balance: 4000
# Enter the amount to withdraw: 1500
# Withdraw: 1500, New Balance: 2500
